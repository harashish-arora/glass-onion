# %% [markdown]
# To rerun the training process from scratch, delete the folder model

# %% [markdown]
# Accordingly move datasets into the data folder depending on what data you want to test/train on, and name them test.csv and train.csv respectively

# %%
# %%time
# !python train.py
# Out:
# Loading datasets...
# Featurizing molecules...
# Computing features for 8312 molecules...
# Featurizing: 100%|██████████████████████████| 8312/8312 [02:42<00:00, 51.27it/s]
# Computing features for 100 molecules...
# Featurizing: 100%|████████████████████████████| 100/100 [00:03<00:00, 26.96it/s]
# Train shape: (8312, 1624)
# Test shape:  (100, 1624)
# Training CatBoost Regressor...
# 0:	learn: 2.1527760	total: 167ms	remaining: 8m 20s
# 200:	learn: 0.8893957	total: 12.5s	remaining: 2m 53s
# 400:	learn: 0.7812592	total: 22.6s	remaining: 2m 26s
# 600:	learn: 0.7062258	total: 32.5s	remaining: 2m 9s
# 800:	learn: 0.6430349	total: 41.8s	remaining: 1m 54s
# 1000:	learn: 0.5939442	total: 52.2s	remaining: 1m 44s
# 1200:	learn: 0.5538848	total: 1m 2s	remaining: 1m 34s
# 1400:	learn: 0.5184642	total: 1m 15s	remaining: 1m 26s
# 1600:	learn: 0.4879656	total: 1m 26s	remaining: 1m 15s
# 1800:	learn: 0.4601981	total: 1m 37s	remaining: 1m 4s
# 2000:	learn: 0.4349727	total: 1m 48s	remaining: 54s
# 2200:	learn: 0.4127398	total: 2m 8s	remaining: 46.6s
# 2400:	learn: 0.3910832	total: 2m 19s	remaining: 34.7s
# 2600:	learn: 0.3718059	total: 2m 31s	remaining: 23.2s
# 2800:	learn: 0.3535191	total: 2m 43s	remaining: 11.6s
# 2999:	learn: 0.3366179	total: 2m 53s	remaining: 0us
#
# Evaluating on Test Set...
#
# Results
# RMSE: 0.8266
# MAE: 0.6279
# R²: 0.5737
# Saving model to ./model/model.joblib...
# Done.
# CPU times: user 3.2 s, sys: 1.11 s, total: 4.31 s
# Wall time: 5min 48s

# %%
# %%time
# !python eval_test.py
# Out:
# Loading test data from ./data/test.csv...
# Loading model from ./model/model.joblib...
# Running inference on 100 molecules...
# Computing features for 100 molecules...
# Featurizing: 100%|████████████████████████████| 100/100 [00:03<00:00, 28.71it/s]
#
# Results:
# RMSE: 0.8266
# MAE: 0.6279
# R²: 0.5737
#
# Inference Speed:
# Total Time: 0.0437 s
# Throughput: 2287 mol/s
# CPU times: user 35.4 ms, sys: 17 ms, total: 52.4 ms
# Wall time: 6.28 s
