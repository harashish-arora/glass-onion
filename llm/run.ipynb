# %%
# !python survey.py
# Out:
# /Users/dhairyakuchhal/Desktop/Dhairya/glass-onion/LLM/survey.py:17: FutureWarning:
#
# All support for the `google.generativeai` package has ended. It will no longer be receiving
# updates or bug fixes. Please switch to the `google.genai` package as soon as possible.
# See README for more details:
#
# https://github.com/google-gemini/deprecated-generative-ai-python/blob/main/README.md
#
#   import google.generativeai as genai
# Loaded 15 mixtures from file - explanations_summary.csv
# Data randomized.
# Using Claude Client.
# Starting survey on 15 mixtures...
# 100%|███████████████████████████████████████████| 15/15 [05:34<00:00, 22.30s/it]
#
# Survey Complete. Results saved to llm_survey_pipeline_results.json
# Total API Calls: 45

# %%
# !python survey_claude.py
# Out:
# /Users/dhairyakuchhal/Desktop/Dhairya/glass-onion/LLM/survey_claude.py:17: FutureWarning:
#
# All support for the `google.generativeai` package has ended. It will no longer be receiving
# updates or bug fixes. Please switch to the `google.genai` package as soon as possible.
# See README for more details:
#
# https://github.com/google-gemini/deprecated-generative-ai-python/blob/main/README.md
#
#   import google.generativeai as genai
# Loaded 15 mixtures from file - explanations_summary.csv
# Data randomized.
# Using Claude Client.
# Starting survey on 15 mixtures...
# 100%|███████████████████████████████████████████| 15/15 [05:05<00:00, 20.36s/it]
#
# Survey Complete. Results saved to llm_survey_pipeline_results_claude.json
# Total API Calls: 45

# %%
# !python survey_deepseek.py
# Out:
# Loaded 15 mixtures from file - explanations_summary.csv
# Data randomized.
# Using DeepSeek Client (deepseek-reasoner).
# Starting survey on 15 mixtures...
# 100%|██████████████████████████████████████████| 15/15 [34:21<00:00, 137.45s/it]
#
# Survey Complete. Results saved to llm_survey_pipeline_results_deepseek.json
# Total API Calls: 45
