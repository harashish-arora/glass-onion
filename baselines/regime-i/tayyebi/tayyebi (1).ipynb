# %%
# !pip install rdkit mordred

# %%
# !mkdir tayyebi

# %%
# !mkdir all_datasets
# Out:
# mkdir: cannot create directory ‘all_datasets’: File exists

# %%
# !cd all_datasets && mkdir aqsoldb && mkdir esol && mkdir sc2

# %%
# !cd tayyebi && python tayyebi_5seeds.py
# Out:
# ...
# Tayyebi et al. Baseline - 5 Seed Evaluation
# Methods: Mordred+RF and Morgan-2048+RF
# ...
#
# ...
# DATASET: AqSolDB
# ...
# Train: 7480, Test: 832
#
#   Precomputing features (once for all seeds)...
#   Computing Morgan-2048 features...
#   [Train] Generating Morgan-2048 fingerprints...
#   [Test] Generating Morgan-2048 fingerprints...
#   Computing Mordred features...
#   [Train] Calculating Mordred descriptors...
# ...
# 100% 7479/7479 [15:22<00:00,  8.11it/s]
#   [Test] Calculating Mordred descriptors...
# 100% 832/832 [01:46<00:00,  7.85it/s]
#     Mordred features after filtering: 309
#   Feature computation complete!
#
#   Seed 42...
#     Morgan-2048: RMSE=1.2351, R²=0.6846
#     Mordred:     RMSE=0.9051, R²=0.8306
#     Time: 320.3s
#   Seed 101...
#     Morgan-2048: RMSE=1.2406, R²=0.6818
#     Mordred:     RMSE=0.9111, R²=0.8284
#     Time: 323.8s
#   Seed 123...
#     Morgan-2048: RMSE=1.2407, R²=0.6818
#     Mordred:     RMSE=0.9042, R²=0.8310
#     Time: 319.6s
#   Seed 456...
# ...
