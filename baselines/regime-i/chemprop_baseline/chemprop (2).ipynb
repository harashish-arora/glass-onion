# %%
# !pip install chemprop

# %%
# !mkdir all_datasets

# %%
# !cd all_datasets && mkdir aqsoldb && mkdir esol && mkdir sc2

# %%
# !mkdir chemprop_baseline

# %%
# !cd chemprop_baseline && python chemprop_5seeds.py
# Out:
# ...
# ChemProp Baseline - 5 Seed Evaluation
# Using ChemProp 2.x CLI
# ...
# ChemProp version: 2.2.2
#
# ...
# DATASET: AqSolDB
# ...
# Train: 7480, Test: 832
#
#   Seed 42...
#     Filtered 1 invalid SMILES
#     Training with seed 42...
#     Model saved at: chemprop_checkpoints/aqsoldb_seed_42/model_0/best.pt
#     Predicting on test set...
#     RMSE: 0.8712, R²: 0.8431
#     Time: 138.6s
#
#   Seed 101...
#     Filtered 1 invalid SMILES
#     Training with seed 101...
#     Model saved at: chemprop_checkpoints/aqsoldb_seed_101/model_0/best.pt
#     Predicting on test set...
#     RMSE: 0.9018, R²: 0.8319
#     Time: 136.8s
#
#   Seed 123...
#     Filtered 1 invalid SMILES
#     Training with seed 123...
#     Model saved at: chemprop_checkpoints/aqsoldb_seed_123/model_0/best.pt
#     Predicting on test set...
#     RMSE: 0.8578, R²: 0.8479
#     Time: 138.7s
#
#   Seed 456...
#     Filtered 1 invalid SMILES
#     Training with seed 456...
# ...
